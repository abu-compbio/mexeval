# %% [markdown]
# # This notebook is used to plot figure 1 of epistasis paper by randomly sampling a gene sets from pairs for each gene

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import os
import gc
from scipy.stats.stats import pearsonr
from itertools import combinations
import random
import multiprocessing
import concurrent.futures
import string
random.seed(1234)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/epistasis_codes/mutex_data
# Out:
# /content/drive/.shortcut-targets-by-id/1M7ksQHsnBabT6t_aAy6H6k_JHTqvUBjb/epistasis_codes/mutex_data

# %% [markdown]
# ## IntAct

# %%
inpath_intact = '../mutex_data/'
intact_edge_file = inpath_intact+'intact_nodupl_edge_file.txt'
intact_index_file = inpath_intact+'intact_nodupl_index_file.txt'

with open(intact_index_file, 'r') as f:
    indices = {line.split()[0]:line.split()[1] for line in f.readlines()}

with open(intact_edge_file, 'r') as f:
    edges = [(indices[line.split()[0]].upper(),indices[line.split()[1]].upper()) for line in f.readlines()]
len(edges)

intact_genes_list = list(indices.values())
intact_genes_list[:5]
# Out:
# ['""CHEBI', '100147744', '1B', '1EFV', '1KLA']

# %% [markdown]
# ## COSMIC

# %%
inpath_cosmic = '../mutex_data/'
cosmic_infile = inpath_cosmic+'Census_allFri_Apr_26_12_49_57_2019.tsv'
with open(cosmic_infile,'r') as f:
    cosmic_genes = [line.split()[0].upper() for line in f.readlines()[1:]]
print(len(cosmic_genes))
# cosmic_genes
# Out:
# 723

# %% [markdown]
# ## Functions

# %%
def set_input_file_paths(methods, c, t):
    '''set input paths as per the location of the MEX results
    m:methods, c: cancer type, t: threshold'''
    
    strat_list=['COADREAD']
    dict_infile = {}
    dict_infile_intact = {}
    for m in methods:
        if m == 'discover':
            suffix = '{}_mutation_filtered_ep_data/{}_{}_result_mutations_all_genes_q1.0_normal_{}.txt'.format(m,c,m,t)
            suffix_intact = '{}_mutation_filtered_ep_data/{}_pairs_q1.0_normal_intact_filtered_subset{}.txt'.format(m,c,t)
        elif m == 'discover_strat':
            suffix = '{}_mutation_filtered_ep_data/{}_{}_result_mutations_all_genes_q1.0_stratified_{}.txt'.format('discover',c,'discover',t)
            suffix_intact = '{}_mutation_filtered_ep_data/{}_pairs_q1.0_stratified_intact_filtered_subset{}.txt'.format('discover',c,t)    
        else:
            suffix = '{}_mutation_filtered_ep_data/{}_{}_result_mutations_all_genes_{}.txt'.format(m,c,m,t)
            suffix_intact = '{}_mutation_filtered_ep_data/{}_{}_pairs_intact_filtered_subset{}.txt'.format(m,c,m,t)

        dict_infile[m] = '../mutex_data/' + suffix
        dict_infile_intact[m] = '../mutex_data/' + suffix_intact
    
    return dict_infile, dict_infile_intact

def load_cgcg_pairs(methods,dict_infile, ref_genes=cosmic_genes):
    '''
    load mutual exclusivity values for CGC-CGC pairs
    methods: mutual exclusivity methods, ref_genes=reference driver genes (COSMIC)
    '''
    d_out ={}
    for m in tqdm(methods):
        d_nb={}
        infile=dict_infile[m]
        with open(infile) as f:
            for line in tqdm(f.readlines()):
                line=line.split()
                g1=line[1]
                g2=line[2]
                if g1 in ref_genes and g2 in ref_genes:
                    if g1 not in d_nb:
                        d_nb[g1]={}
                    if g2 not in d_nb:
                        d_nb[g2]={}
                    d_nb[g1][g2]=float(line[3])
                    d_nb[g2][g1]=float(line[3])
        d_out[m]=d_nb

    return d_out

def get_sig_dict(d,m):
    '''get percentage significance from a dictionary of CGC-CGC neighbors
    '''
    d_out={}
    for g in d:
        count=0
        for k,v in d[g].items():
            if m=='wext' and v==0:
                continue
            elif v<0.05:
                count+=1
        d_out[g]= float(count)/float(len(d[g]))
    
    return d_out
                
def get_sig_dict_from_random_sampling(d,d_nb,method):
    '''get percentage significance through random sampling
    '''
    common_genes = set.intersection(set(d), set(d_nb))
    dict_sig = {}
    for g in common_genes:
        l_temp=[]
        for i in range(100):
            k_temp = {k:d[g][k] for k in random.sample(list(d[g]),k=len(d_nb[g]))}
            
            count=0
            for k,v in k_temp.items():
                if method=='wext' and v==0:
                    continue
                elif v<0.05:
                    count+=1
            
            l_temp.append(float(count)/len(k_temp))
        
        dict_sig[g] = np.mean(l_temp)
    
    return dict_sig

def plot_from_dict(d, d_mla,ax, annotation_threshold_y=-0.0,annotation_threhsold_x=1.5,title=''):
    l_mla_all = []
    l_sig_all = []
    
    l_mla_nonrare = []
    l_sig_nonrare = []
    
    l_mla_rare = []
    l_sig_rare = []
    
    for k,v in d.items():
        if k in d_mla:
            l_mla_all.append(d_mla[k])
            l_sig_all.append(v)
            
                
    ax.scatter(l_mla_all,l_sig_all, c='K',alpha=0.3)
    
    r,p = pearsonr(l_mla_all,l_sig_all)
    print('r:{}\nP:{}'.format(r,p))
    ax.text(0.85, 0.97, 'r = {}\nP = {:.3g}'.format(round(r,2), p), ha='left', va='top', fontsize=8,transform=ax.transAxes)
    
    for k,v in d.items():
        if v>annotation_threshold_y and d_mla[k]<annotation_threhsold_x:
            ax.annotate(k, (d_mla[k],v), ha='left',va='top',xytext=(d_mla[k]+0.08,v-0.01))
    
#     ax.set_xlim(min(l_mla_all)-0.5,max(l_mla_all)+0.5)
    ax.set_xlim(min_mla-0.5,max_mla+0.5)
    ax.set_ylim(-0.05,1.05)        
    labels = [str(int(round(float(item)*100))) for item in ax.get_yticks()]
    print(labels)
    
    ax.set_yticklabels(labels)
    ax.set_xlabel('Mutation Load Association (MLA)')
    ax.set_ylabel('Percentage of Significant Findings (P<0.05)')
    ax.set_title(title)# + '| {} total genes, {} rare, {} nonrare'.format(len(l_sig_all), len(l_sig_rare),len(l_sig_nonrare)) )
    
        
    
def plot_from_dict_arrow(d,d_nb, d_mla,ax, annotation_threshold_y=-0.0,annotation_threhsold_x=1.5,title='',c1='C3',c2='K'):
    '''plot with direction of arrow going from dict d to dict d_nb
    annotation thresholds define the points until which gene annotation 
    is done in the graph 
    '''
    
    l_mla_all = []
    l_sig_all = []
    l_sig_nb = []
    
    
    for k,v in d.items():
        if k in d_mla and k in d_nb:
            l_mla_all.append(d_mla[k])
            l_sig_all.append(v)
            l_sig_nb.append(d_nb[k])
                
    ax.scatter(l_mla_all,l_sig_nb, c=c1,alpha=0.7)
    ax.scatter(l_mla_all,l_sig_all, c=c2,alpha=0.2)
    
    
    r,p = pearsonr(l_mla_all,l_sig_nb)
    print('r:{}\nP:{}'.format(r,p))
    ax.text(0.85, 0.97, 'r = {}\nP = {:.3g}'.format(round(r,2), p), ha='left', va='top', fontsize=8,transform=ax.transAxes)
    
    for k,v in d_nb.items():
        if v>annotation_threshold_y and d_mla[k]<annotation_threhsold_x:
            ax.annotate(k, (d_mla[k],v), ha='left',va='top',xytext=(d_mla[k]+0.08,v-0.01))
            
            
    for _mla,_all,_nb in zip(l_mla_all, l_sig_all,l_sig_nb):
        if _mla<annotation_threhsold_x and abs(_all-_nb)>0.01:
            if _all<_nb:
                ax.annotate("", xytext=(_mla, _all), xy=(_mla, _all+_nb-_all), arrowprops=dict(arrowstyle="->", alpha=0.2))
#                 ax.arrow(_mla,_all,0.0,_nb-_all, alpha=0.5,lw=2, length_includes_head=True)
#                 ax.quiver(_mla,_all,0.0,(_all-_nb), alpha=0.5,lw=0.1,headwidth=0.05, headlength=0.1,)
            else:
                ax.annotate("", xytext=(_mla, _all), xy=(_mla, _all+_nb-_all), arrowprops=dict(arrowstyle="->", alpha=0.2))
#                 ax.arrow(_mla,_all,0.0,_nb-_all, alpha=0.5,lw=2, length_includes_head=True)

#     for k,v in d.items():
#         if k in d_nb:
#             if d_mla[k]<annotation_threhsold_x:
#                 ax.arrow(d_mla[k], v, d_mla[k],d_nb[k])
            
        #     ax.arrow(l_mla_all[0],l_sig_all[0],l_sig_all[0]-l_sig_nb[0], l_mla_all[0]-l_mla_all[0],
#             shape='full', color='K', lw=1/2., length_includes_head=True, 
#             zorder=0)
#     ax.set_xlim(min(l_mla_all)-0.5,max(l_mla_all)+0.5)
    ax.set_xlim(min_mla-0.5,max_mla+0.5)
    ax.set_ylim(-0.05,1.05)        
    labels = [str(int(round(float(item)*100))) for item in ax.get_yticks()]

    ax.set_yticklabels(labels)        
    ax.set_xlabel('Mutation Load Association (MLA)')
    ax.set_ylabel('Percentage of Significant Findings (P<0.05)')
    ax.set_title(title)# + '| {} total genes, {} rare, {} nonrare'.format(len(l_sig_all), len(l_sig_rare),len(l_sig_nonrare)) )
    

def get_mla_limits(d_y,d_x):
    ''' get max and min MLA for same x axis
        d_y: sig values
        d_x: MLA values
    '''
    l = []
    for k,v in d_y.items():
        if k in d_x:
            l.append(d_x[k])
    
    return max(l), min(l)

# %% [markdown]
# ## LOAD MUTEX VALUES

# %%
c='BRCA' # cancer type
t=20 #mutation threshold
methods = ['discover','discover_strat','fishers','wext']#'discover_strat','discover','discover_strat']#
#methods = ['discover','fishers','wext']#'discover_strat','discover','discover_strat']#
inpath_mla = '../mutex_data/'

# inpath_sig = '../out_main/evaluation_results/significance_files/{}_t{}/'.format(c,t)


## Load MLA
MLA_infile = inpath_mla + 'MLA_ep_mutation_filtered_all_genes/{}_MLA_standardized.txt'.format(c)
with open(MLA_infile, 'r') as f:
    MLA = {line.split()[0]: float(line.split()[1]) for line in f.readlines()}
    
    
dict_infile, dict_infile_intact = set_input_file_paths(methods, c,t)

dict_cg_cg = load_cgcg_pairs(methods,dict_infile)
dict_cg_cg_nb = load_cgcg_pairs(methods,dict_infile_intact)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=28204.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=28204.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=28204.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=28204.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))

# %%
d_sig_m = get_sig_dict(dict_cg_cg[methods[0]], methods[0])
d_sig_m
# Out:
# {'AKAP9': 0.1724137931034483,
#  'AKT1': 0.7068965517241379,
#  'ARID1A': 0.2413793103448276,
#  'ARID1B': 0.10344827586206896,
#  'ATM': 0.1724137931034483,
#  'ATRX': 0.06896551724137931,
#  'BIRC6': 0.10344827586206896,
#  'BRCA1': 0.1724137931034483,
#  'BRCA2': 0.13793103448275862,
#  'CBFB': 0.29310344827586204,
#  'CDH1': 0.5344827586206896,
#  'CHD4': 0.1206896551724138,
#  'CREBBP': 0.017241379310344827,
#  'CSMD3': 0.22413793103448276,
#  'CTCF': 0.43103448275862066,
#  'ERBB2': 0.06896551724137931,
#  'FAM135B': 0.1206896551724138,
#  'FAT1': 0.13793103448275862,
#  'FAT3': 0.1896551724137931,
#  'FAT4': 0.06896551724137931,
#  'FLNA': 0.08620689655172414,
#  'FOXA1': 0.20689655172413793,
#  'GATA3': 0.6896551724137931,
#  'GRIN2A': 0.08620689655172414,
#  'KAT6B': 0.06896551724137931,
#  'KDM6A': 0.08620689655172414,
#  'KMT2A': 0.10344827586206896,
#  'KMT2C': 0.10344827586206896,
#  'KMT2D': 0.10344827586206896,
#  'LRP1B': 0.10344827586206896,
#  'MAP2K4': 0.4827586206896552,
#  'MAP3K1': 0.6724137931034483,
#  'MED12': 0.13793103448275862,
#  'MLLT4': 0.06896551724137931,
#  'MTOR': 0.05172413793103448,
#  'MUC16': 0.22413793103448276,
#  'MUC4': 0.1896551724137931,
#  'MYH9': 0.08620689655172414,
#  'NCOR1': 0.29310344827586204,
#  'NF1': 0.10344827586206896,
#  'NOTCH2': 0.15517241379310345,
#  'PDE4DIP': 0.10344827586206896,
#  'PIK3CA': 0.25862068965517243,
#  'PIK3R1': 0.20689655172413793,
#  'PREX2': 0.08620689655172414,
#  'PTEN': 0.1896551724137931,
#  'PTPRD': 0.06896551724137931,
#  'RANBP2': 0.034482758620689655,
#  'RB1': 0.2413793103448276,
#  'RNF213': 0.05172413793103448,
#  'RUNX1': 0.5344827586206896,
#  'SETD2': 0.10344827586206896,
#  'SF3B1': 0.1206896551724138,
#  'SPEN': 0.05172413793103448,
#  'TBX3': 0.1896551724137931,
#  'TP53': 0.46551724137931033,
#  'TPR': 0.06896551724137931,
#  'UBR5': 0.1206896551724138,
#  'ZFHX3': 0.08620689655172414}

# %%
## plot percentage significance

dict_methods = {'discover': 'DISCOVER',
               'discover_strat': 'DISCOVER Strat',
               'fishers': 'Fisher\'s Exact Test',
               'megsa': 'MEGSA',
               'memo': 'MEMO',
               'wext': 'WExT'}


sfx = '../results_main/evaluation_results/figures_v8_random_fig3ep_for paper/'

outpath_cgcg_nb = sfx

if not os.path.exists(outpath_cgcg_nb):
    os.makedirs(outpath_cgcg_nb)

#margins for annotation of genes within plot
#use 1.2,2.2,...,4.2 val_x for different cancer types
#val_x = -1.2
val_x = 1.2
val_y = -0.1

fig, axes = plt.subplots(len(methods),3,figsize=(25,28)) #adjust figsize for the plot .for 3 methods: (25,20)
letters = list(string.ascii_uppercase)[:len(methods)*3] #annotate figures alphabetiaclly
axiter=axes.flat #flatten axis to a list
for i,m in tqdm(enumerate(methods)):
    
    if m=='discover_strat':
        dict_sig = get_sig_dict(dict_cg_cg[m],m)
        dict_sig_discover = get_sig_dict(dict_cg_cg['discover'],'discover') #load discover to compare
        dict_sig_rand = get_sig_dict_from_random_sampling(dict_cg_cg[m],dict_cg_cg_nb[m],m) 
        dict_sig_rand_discover = get_sig_dict_from_random_sampling(dict_cg_cg['discover'],dict_cg_cg_nb['discover'],'discover')
        dict_sig_cg_cg_nb = get_sig_dict(dict_cg_cg_nb[m], m)

        #main plot
        max_mla, min_mla = get_mla_limits(dict_sig,MLA)
        ax=axiter[3*i]
        letter=letters[3*i]
        title = '{} COSMIC-COSMIC pairs'.format(dict_methods[m])
        plot_from_dict_arrow(dict_sig_discover,dict_sig,MLA,ax,title=title,c1='C0', annotation_threhsold_x=val_x, annotation_threshold_y=val_y)

        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')

        #random sampled plot
        ax=axiter[3*i+1]
        letter=letters[3*i+1]
        title = '{} COSMIC-COSMIC pairs (random)'.format(dict_methods[m])
        plot_from_dict_arrow(dict_sig_rand_discover,dict_sig_rand,MLA,ax,title=title,c1='C0', annotation_threhsold_x=val_x, annotation_threshold_y=val_y)

        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')
        
        #neighbors plot
        ax=axiter[3*i+2]
        letter=letters[3*i+2]
        title = '{} COSMIC-COSMIC neighbors'.format(dict_methods[m])
        plot_from_dict_arrow(dict_sig_rand,dict_sig_cg_cg_nb,MLA,ax,title=title,c2='C0', annotation_threhsold_x=val_x, annotation_threshold_y=val_y)

        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')
    
    else:
        dict_sig = get_sig_dict(dict_cg_cg[m], m)
        dict_sig_rand = get_sig_dict_from_random_sampling(dict_cg_cg[m],dict_cg_cg_nb[m],m)
        dict_sig_cg_cg_nb = get_sig_dict(dict_cg_cg_nb[m], m)

        #main plot
        max_mla, min_mla = get_mla_limits(dict_sig,MLA)
        ax=axiter[3*i]
        letter=letters[3*i]
        title = '{} COSMIC-COSMIC pairs'.format(dict_methods[m])
        plot_from_dict(dict_sig,MLA,ax,title=title,annotation_threhsold_x=val_x,annotation_threshold_y=val_y)

        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')

        #randomized plot
        ax=axiter[3*i+1]
        letter=letters[3*i+1]
        title = '{} COSMIC-COSMIC pairs (random)'.format(dict_methods[m])
        plot_from_dict(dict_sig_rand,MLA,ax,title=title,annotation_threhsold_x=val_x,annotation_threshold_y=val_y)
        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')
         
        ax=axiter[3*i+2]
        letter=letters[3*i+2]
        title = '{} COSMIC-COSMIC neighbors'.format(dict_methods[m])
        plot_from_dict_arrow(dict_sig_rand,dict_sig_cg_cg_nb,MLA,ax,title=title, annotation_threhsold_x=val_x, annotation_threshold_y=val_y)

        ax.text(-0.06, 1.1, letter, transform=ax.transAxes,
              fontsize=16, fontweight='bold', va='top', ha='right')

plt.savefig(outpath_cgcg_nb+'{}_t{}_percsig_random_fig1.pdf'.format(c,t),format='pdf', bbox_inches='tight')
plt.show()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# r:-0.854110753311828
# P:8.024622744359098e-18
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.9138507369486855
# P:2.9482364639055353e-07
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.26546613329473057
# P:0.30310333058320776
# r:-0.8593675011173739
# P:3.0387905170505093e-18
# r:-0.8804447977720554
# P:3.115498715230668e-06
# r:-0.26546613329473057
# P:0.30310333058320776
# r:-0.5212760834260006
# P:2.3038707572462087e-05
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.4870596262817808
# P:0.04737843206470923
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.044333778395738314
# P:0.86583472452344
# r:-0.8740057376630697
# P:1.630438358491026e-19
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.9074408569144582
# P:4.954933460393065e-07
# ['-20', '0', '20', '40', '60', '80', '100', '120']
# r:-0.24850225990327618
# P:0.3361701820619029

# %%
len(dict_cgcg_intact[m]),len(dict_sig_rand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-4295935b53a2> in <module>()
# ----> 1 len(dict_cgcg_intact[m]),len(dict_sig_rand)
#
# NameError: name 'dict_cgcg_intact' is not defined

# %% [markdown]
# ## Testing individual genes - a separate section for testing select genes and their properties

# %%
binary_inpath = '../mutex_data/binary_matrices_all_genes_ep_mutation_filtered/'
binary_infile = binary_inpath + '{}_TML_binary_sm.txt'.format(c)

df = pd.read_csv(binary_infile, sep='\t', header=0,index_col=0)

genes=df.columns.tolist()

dict_gene_vs_patients = {}

for g in genes:
    dict_gene_vs_patients[g]=df.index[df[g] == 1].tolist()
    
dict_gene_vs_patients
# Out:
# {'A1BG': ['TCGA-FD-A62P-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-SY-A9G5-01A'],
#  'A1CF': ['TCGA-FJ-A3ZF-01A', 'TCGA-GU-A767-01A', 'TCGA-XF-A9SV-01A'],
#  'A2M': ['TCGA-5N-A9KI-01A',
#   'TCGA-BL-A3JM-01A',
#   'TCGA-BT-A20J-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-C4-A0EZ-01A',
#   'TCGA-CF-A1HS-01A',
#   'TCGA-CF-A47Y-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-G2-A3IB-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-K4-A4AC-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9SI-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-ZF-A9R2-01A'],
#  'A2ML1': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-A1AF-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-A6B5-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-K4-A83P-01A',
#   'TCGA-R3-A69X-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-XF-AAMG-01A'],
#  'A3GALT2': ['TCGA-ZF-A9RC-01A'],
#  'A4GALT': ['TCGA-KQ-A41N-01A'],
#  'A4GNT': ['TCGA-DK-AA6L-01A', 'TCGA-DK-AA6U-01A', 'TCGA-K4-A3WS-01A'],
#  'AAAS': ['TCGA-FD-A62P-01A', 'TCGA-FD-A6TC-01A', 'TCGA-MV-A51V-01A'],
#  'AACS': ['TCGA-CU-A5W6-01A', 'TCGA-LT-A5Z6-01A'],
#  'AADAC': ['TCGA-FD-A62P-01A', 'TCGA-KQ-A41N-01A'],
#  'AADACL2': ['TCGA-C4-A0F7-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GU-A766-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'AADACL3': ['TCGA-FD-A3B4-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-AAML-01A'],
#  'AADACL4': ['TCGA-CF-A3MH-01A',
#   'TCGA-FD-A3B3-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-GC-A6I1-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'AADAT': ['TCGA-BT-A42E-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-XF-A9SZ-01A',
#   'TCGA-ZF-A9RF-01A'],
#  'AAED1': ['TCGA-MV-A51V-01A'],
#  'AAGAB': ['TCGA-4Z-AA7M-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'AAK1': ['TCGA-DK-AA77-01A', 'TCGA-K4-A54R-01A', 'TCGA-MV-A51V-01A'],
#  'AAMP': ['TCGA-4Z-AA7Q-01A', 'TCGA-FJ-A3Z7-01A', 'TCGA-ZF-AA53-01A'],
#  'AANAT': ['TCGA-BT-A2LA-01A', 'TCGA-UY-A78L-01A'],
#  'AAR2': ['TCGA-DK-A6B6-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-XF-A8HG-01A',
#   'TCGA-ZF-A9R0-01A'],
#  'AARD': ['TCGA-GV-A3JV-01A', 'TCGA-XF-AAMG-01A'],
#  'AARS': ['TCGA-DK-A3IQ-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6S-01A',
#   'TCGA-XF-A9SK-01A'],
#  'AARS2': ['TCGA-5N-A9KM-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-AA4W-01A',
#   'TCGA-ZF-AA54-01A'],
#  'AARSD1': ['TCGA-E7-A8O8-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-XF-AAMZ-01A'],
#  'AASDH': ['TCGA-4Z-AA80-01A',
#   'TCGA-C4-A0F6-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-DK-A6AV-01A',
#   'TCGA-E7-A3X6-01A',
#   'TCGA-FD-A3SJ-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-GU-A762-01A',
#   'TCGA-R3-A69X-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-A9SL-01A',
#   'TCGA-ZF-AA54-01A'],
#  'AASDHPPT': ['TCGA-KQ-A41N-01A', 'TCGA-YC-A89H-01A'],
#  'AASS': ['TCGA-DK-A3WW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GV-A3JV-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'AATF': ['TCGA-DK-A1AG-01A',
#   'TCGA-G2-A2EC-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-XF-A9SJ-01A'],
#  'AATK': ['TCGA-CF-A9FL-01A',
#   'TCGA-DK-A1AA-01A',
#   'TCGA-DK-A6B2-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-K4-AAQO-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-ZF-AA4V-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ABAT': ['TCGA-DK-AA71-01A', 'TCGA-K4-A83P-01A'],
#  'ABCA1': ['TCGA-DK-A1AB-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A3N5-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'ABCA10': ['TCGA-BT-A0YX-01A',
#   'TCGA-BT-A20O-01A',
#   'TCGA-BT-A20P-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-ZF-A9R3-01A'],
#  'ABCA12': ['TCGA-2F-A9KO-01A',
#   'TCGA-4Z-AA7Q-01A',
#   'TCGA-4Z-AA83-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-CU-A0YN-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A6TB-01A',
#   'TCGA-FD-A6TF-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-GU-A767-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA4W-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ABCA13': ['TCGA-4Z-AA7M-01A',
#   'TCGA-4Z-AA7W-01A',
#   'TCGA-5N-A9KI-01A',
#   'TCGA-BT-A20N-01A',
#   'TCGA-BT-A20T-01A',
#   'TCGA-BT-A20X-01A',
#   'TCGA-BT-A42C-01A',
#   'TCGA-C4-A0F0-01A',
#   'TCGA-CF-A5UA-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6P-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A5KF-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A3SM-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A6TH-01A',
#   'TCGA-FD-A6TI-01A',
#   'TCGA-FJ-A3Z7-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A9SH-01A',
#   'TCGA-XF-A9SJ-01A',
#   'TCGA-XF-AAMQ-01A',
#   'TCGA-ZF-A9RN-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ABCA2': ['TCGA-C4-A0EZ-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-K4-A4AC-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A8OB-01A',
#   'TCGA-XF-A9SG-01A'],
#  'ABCA3': ['TCGA-4Z-AA7Q-01A',
#   'TCGA-4Z-AA81-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-GU-A767-01A',
#   'TCGA-UY-A9PA-01A',
#   'TCGA-XF-A8HE-01A'],
#  'ABCA4': ['TCGA-4Z-AA81-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A62O-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A9PE-01A',
#   'TCGA-ZF-A9R0-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ABCA5': ['TCGA-BT-A20T-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3WY-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A4XJ-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-A8HH-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-AAN5-01A'],
#  'ABCA6': ['TCGA-DK-A1A3-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-GU-A766-01A',
#   'TCGA-GV-A3QG-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-ZF-A9RC-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ABCA7': ['TCGA-BT-A3PK-01A',
#   'TCGA-BT-A42F-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GC-A6I1-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-PQ-A6FN-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-XF-A9T2-01A'],
#  'ABCA8': ['TCGA-4Z-AA84-01A',
#   'TCGA-BL-A3JM-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-BT-A20O-01A',
#   'TCGA-CU-A0YN-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X2-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-A6B5-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A8HC-01A'],
#  'ABCA9': ['TCGA-BT-A20O-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-GV-A3QG-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-AAMH-01A',
#   'TCGA-XF-AAN5-01A',
#   'TCGA-YF-AA3L-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ABCB1': ['TCGA-4Z-AA86-01A',
#   'TCGA-CU-A5W6-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6S-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-FD-A3B4-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ABCB10': ['TCGA-4Z-AA83-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-GU-A42Q-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAMZ-01A',
#   'TCGA-XF-AAN0-01A'],
#  'ABCB11': ['TCGA-DK-A2I2-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-UY-A78K-01A'],
#  'ABCB4': ['TCGA-2F-A9KO-01A',
#   'TCGA-4Z-AA7M-01A',
#   'TCGA-CF-A1HS-01A',
#   'TCGA-CF-A47T-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-FJ-A3Z7-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-XF-A9SU-01A',
#   'TCGA-XF-AAN5-01A'],
#  'ABCB5': ['TCGA-4Z-AA7O-01A',
#   'TCGA-5N-A9KM-01A',
#   'TCGA-BT-A3PH-01A',
#   'TCGA-DK-A1AA-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A5BV-01A',
#   'TCGA-FD-A62P-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-FD-A6TH-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-A8HI-01A',
#   'TCGA-ZF-A9RC-01A',
#   'TCGA-ZF-AA4T-01A'],
#  'ABCB6': ['TCGA-2F-A9KT-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-FD-A5C1-01A',
#   'TCGA-XF-A8HG-01A'],
#  'ABCB7': ['TCGA-BT-A42F-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-XF-AAN1-01A',
#   'TCGA-ZF-AA56-01A'],
#  'ABCB8': ['TCGA-2F-A9KO-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GU-A767-01A',
#   'TCGA-YC-A9TC-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ABCB9': ['TCGA-BT-A3PJ-01A'],
#  'ABCC1': ['TCGA-BT-A42B-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-GD-A2C5-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-AAMX-01A'],
#  'ABCC10': ['TCGA-2F-A9KQ-01A',
#   'TCGA-4Z-AA81-01A',
#   'TCGA-DK-A1AF-01A',
#   'TCGA-DK-A6AV-01A',
#   'TCGA-DK-AA6S-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-GD-A3OQ-01A'],
#  'ABCC11': ['TCGA-4Z-AA7S-01A',
#   'TCGA-BT-A20P-01A',
#   'TCGA-BT-A42E-01A',
#   'TCGA-CF-A1HR-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A3SL-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-GU-AATQ-01A',
#   'TCGA-GV-A3JW-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-XF-AAMR-01A'],
#  'ABCC12': ['TCGA-BT-A2LB-01A',
#   'TCGA-DK-A1AE-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X2-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A62O-01A',
#   'TCGA-GU-A42R-01A',
#   'TCGA-K4-A4AB-01B',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-A9SI-01A',
#   'TCGA-ZF-AA4V-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ABCC2': ['TCGA-4Z-AA89-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GV-A3JZ-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-ZF-A9RD-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ABCC3': ['TCGA-BT-A20N-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-CU-A3QU-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A3IS-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-HQ-A2OF-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-YC-A8S6-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ABCC4': ['TCGA-BT-A20T-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-E7-A678-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-XF-AAMR-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R4-01A'],
#  'ABCC5': ['TCGA-BT-A2LB-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A1AE-01A',
#   'TCGA-DK-A6B2-01A',
#   'TCGA-DK-AA6L-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E7-A678-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A8OB-01A',
#   'TCGA-UY-A9PD-01A',
#   'TCGA-XF-A9SG-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-A9RG-01A',
#   'TCGA-ZF-AA51-01A',
#   'TCGA-ZF-AA5P-01A'],
#  'ABCC6': ['TCGA-DK-A3IQ-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-UY-A9PD-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-A9T2-01A',
#   'TCGA-XF-AAML-01A'],
#  'ABCC8': ['TCGA-DK-A3IL-01A',
#   'TCGA-DK-A6AV-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-FD-A6TH-01A',
#   'TCGA-FJ-A3Z7-01A',
#   'TCGA-GC-A3RD-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-XF-AAN2-01A'],
#  'ABCC9': ['TCGA-4Z-AA7Y-01A',
#   'TCGA-BT-A20W-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A1A7-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-A6B2-01A',
#   'TCGA-E7-A5KE-01A',
#   'TCGA-FD-A3B4-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78N-01A',
#   'TCGA-UY-A8OD-01A',
#   'TCGA-XF-A8HF-01A'],
#  'ABCD1': ['TCGA-BT-A2LA-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-G2-AA3D-01A',
#   'TCGA-ZF-AA54-01A'],
#  'ABCD2': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-GV-A3QF-01A',
#   'TCGA-KQ-A41O-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A8OB-01A',
#   'TCGA-XF-AAMG-01A'],
#  'ABCD3': ['TCGA-BT-A42C-01A',
#   'TCGA-CF-A27C-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FD-A62P-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-AAML-01A'],
#  'ABCD4': ['TCGA-DK-A2I2-01A', 'TCGA-H4-A2HO-01A', 'TCGA-KQ-A41S-01A'],
#  'ABCE1': ['TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-XF-A8HC-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'ABCF1': ['TCGA-G2-A2EO-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9SY-01A'],
#  'ABCF2': ['TCGA-ZF-AA51-01A'],
#  'ABCF3': ['TCGA-BT-A2LA-01A', 'TCGA-FD-A5BX-01A', 'TCGA-XF-AAMG-01A'],
#  'ABCG1': ['TCGA-BT-A42C-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-S5-AA26-01A'],
#  'ABCG2': ['TCGA-DK-A2I1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-GC-A6I1-01A',
#   'TCGA-GV-A40E-01A',
#   'TCGA-XF-A9SX-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-AA52-01A'],
#  'ABCG4': ['TCGA-DK-A1AA-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-FT-A61P-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GV-A40G-01A'],
#  'ABCG5': ['TCGA-4Z-AA7R-01A',
#   'TCGA-DK-A3IQ-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-MV-A51V-01A'],
#  'ABCG8': ['TCGA-UY-A78M-01A'],
#  'ABHD1': ['TCGA-4Z-AA7R-01A', 'TCGA-E7-A5KF-01A', 'TCGA-GD-A76B-01A'],
#  'ABHD10': ['TCGA-DK-A6AW-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-R3-A69X-01A'],
#  'ABHD11': ['TCGA-G2-AA3D-01A',
#   'TCGA-GV-A40G-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78N-01A'],
#  'ABHD12': ['TCGA-4Z-AA86-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-FD-A5BZ-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-YC-A89H-01A'],
#  'ABHD12B': ['TCGA-XF-A9SI-01A'],
#  'ABHD13': ['TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A9SP-01A',
#   'TCGA-YF-AA3L-01A'],
#  'ABHD14A': ['TCGA-XF-AAN2-01A'],
#  'ABHD14B': ['TCGA-E7-A541-01A'],
#  'ABHD15': ['TCGA-4Z-AA84-01A',
#   'TCGA-BL-A5ZZ-01A',
#   'TCGA-DK-A3IQ-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GV-A40G-01A'],
#  'ABHD16A': ['TCGA-BT-A3PH-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-E7-A5KF-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-YF-AA3M-01A'],
#  'ABHD16B': ['TCGA-FD-A3SR-01A'],
#  'ABHD17B': ['TCGA-DK-A6AW-01A'],
#  'ABHD17C': ['TCGA-BT-A3PJ-01A', 'TCGA-XF-AAN2-01A'],
#  'ABHD2': ['TCGA-DK-AA6W-01A'],
#  'ABHD3': ['TCGA-DK-A2I1-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A3N6-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-XF-A9T5-01A'],
#  'ABHD4': ['TCGA-XF-AAML-01A'],
#  'ABHD5': ['TCGA-KQ-A41N-01A'],
#  'ABHD6': ['TCGA-G2-A2ES-01A', 'TCGA-XF-A9SL-01A'],
#  'ABHD8': ['TCGA-GU-AATP-01A', 'TCGA-GV-A3JX-01A', 'TCGA-ZF-AA4W-01A'],
#  'ABI1': ['TCGA-BT-A2LB-01A',
#   'TCGA-DK-A1A7-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-GV-A3QI-01A'],
#  'ABI2': ['TCGA-2F-A9KO-01A',
#   'TCGA-4Z-AA81-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-GC-A4ZW-01A'],
#  'ABI3': ['TCGA-G2-AA3F-01A', 'TCGA-GU-AATP-01A'],
#  'ABI3BP': ['TCGA-BT-A3PH-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-GC-A3WC-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-HQ-A5ND-01A',
#   'TCGA-K4-A83P-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9ST-01A'],
#  'ABL1': ['TCGA-4Z-AA81-01A',
#   'TCGA-BT-A2LA-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-GD-A3OS-01A',
#   'TCGA-XF-A9T6-01A'],
#  'ABL2': ['TCGA-DK-AA6S-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-FD-A3N5-01A',
#   'TCGA-FD-A3SL-01A',
#   'TCGA-XF-A9SI-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R3-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ABLIM1': ['TCGA-BT-A20J-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-FD-A5BT-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-G2-A2EO-01A'],
#  'ABLIM2': ['TCGA-BT-A2LB-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-A3IL-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'ABLIM3': ['TCGA-CU-A0YN-01A', 'TCGA-ZF-A9R7-01A'],
#  'ABR': ['TCGA-DK-A6B2-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-SY-A9G0-01A',
#   'TCGA-XF-A9SL-01A'],
#  'ABRA': ['TCGA-4Z-AA80-01A',
#   'TCGA-BT-A20R-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-GV-A40E-01A',
#   'TCGA-ZF-AA4T-01A'],
#  'ABT1': ['TCGA-E7-A3Y1-01A', 'TCGA-XF-AAN2-01A'],
#  'ABTB1': ['TCGA-DK-A2I1-01A', 'TCGA-ZF-AA4X-01A'],
#  'ABTB2': ['TCGA-GV-A3JX-01A', 'TCGA-GV-A3QI-01A'],
#  'AC003002.6': ['TCGA-FD-A6TC-01A', 'TCGA-MV-A51V-01A', 'TCGA-XF-A9T3-01A'],
#  'AC003006.7': ['TCGA-UY-A9PD-01A'],
#  'AC004076.9': ['TCGA-ZF-AA4X-01A'],
#  'AC004381.6': ['TCGA-4Z-AA7Q-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A9PA-01A'],
#  'AC005609.1': ['TCGA-FD-A3SJ-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-ZF-A9R1-01A'],
#  'AC006435.1': ['TCGA-DK-A1AC-01A', 'TCGA-FD-A3SL-01A', 'TCGA-XF-A9T0-01A'],
#  'AC006486.9': ['TCGA-DK-A1A3-01A'],
#  'AC007956.1': ['TCGA-FD-A43X-01A'],
#  'AC026202.1': ['TCGA-DK-A6B6-01A', 'TCGA-FD-A3N5-01A'],
#  'AC026703.1': ['TCGA-E7-A7DV-01A', 'TCGA-S5-A6DX-01A'],
#  'AC040977.1': ['TCGA-BT-A3PJ-01A'],
#  'AC069368.3': ['TCGA-4Z-AA7W-01A'],
#  'AC104534.3': ['TCGA-GU-A42Q-01A'],
#  'AC129492.6': ['TCGA-BT-A20R-01A'],
#  'ACAA1': ['TCGA-DK-A3WW-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-ZF-A9RF-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ACAA2': ['TCGA-K4-A54R-01A'],
#  'ACACA': ['TCGA-BT-A20U-01A',
#   'TCGA-CF-A47V-01A',
#   'TCGA-CU-A3KJ-01A',
#   'TCGA-CU-A72E-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA6P-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E7-A5KF-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A3SM-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A5BT-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GC-A3RB-01A',
#   'TCGA-GV-A40E-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-AAN0-01A',
#   'TCGA-ZF-A9R2-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ACACB': ['TCGA-4Z-AA7W-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-C4-A0F6-01A',
#   'TCGA-CF-A7I0-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A5KE-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FD-A3SJ-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-HQ-A2OE-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAMZ-01A',
#   'TCGA-XF-AAN0-01A',
#   'TCGA-ZF-A9R5-01A'],
#  'ACAD10': ['TCGA-4Z-AA7W-01A',
#   'TCGA-BT-A20J-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-LC-A66R-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9SU-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ACAD11': ['TCGA-BT-A20V-01A',
#   'TCGA-BT-A42C-01A',
#   'TCGA-BT-A42F-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-ZF-A9RE-01A'],
#  'ACAD8': ['TCGA-BT-A20J-01A', 'TCGA-YF-AA3L-01A', 'TCGA-ZF-AA4W-01A'],
#  'ACAD9': ['TCGA-2F-A9KT-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-UY-A78K-01A'],
#  'ACADL': ['TCGA-E7-A5KE-01A', 'TCGA-K4-AAQO-01A'],
#  'ACADM': ['TCGA-XF-A9SP-01A'],
#  'ACADS': ['TCGA-DK-AA6U-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-FD-A3N6-01A',
#   'TCGA-FD-A5C0-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A78P-01A'],
#  'ACADSB': ['TCGA-BL-A5ZZ-01A', 'TCGA-DK-A1AD-01A', 'TCGA-XF-A9T5-01A'],
#  'ACADVL': ['TCGA-4Z-AA89-01A',
#   'TCGA-BT-A42E-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41R-01A'],
#  'ACAN': ['TCGA-4Z-AA7W-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-CU-A3YL-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-S5-AA26-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-A9SG-01A',
#   'TCGA-XF-A9SJ-01A',
#   'TCGA-YF-AA3L-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ACAP1': ['TCGA-E7-A97P-01A',
#   'TCGA-FD-A3SQ-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-XF-AAMZ-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ACAP2': ['TCGA-DK-A2I4-01A',
#   'TCGA-GV-A3JZ-01A',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-MV-A51V-01A'],
#  'ACAP3': ['TCGA-2F-A9KQ-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-G2-A2EC-01A',
#   'TCGA-R3-A69X-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAMQ-01A'],
#  'ACAT1': ['TCGA-DK-A3WX-01A',
#   'TCGA-XF-A9SJ-01A',
#   'TCGA-ZF-A9R1-01A',
#   'TCGA-ZF-A9R9-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ACAT2': ['TCGA-DK-A6AW-01A'],
#  'ACBD3': ['TCGA-BT-A2LB-01A',
#   'TCGA-C4-A0F7-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-A9SP-01A'],
#  'ACBD4': ['TCGA-5N-A9KM-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-HQ-A2OE-01A'],
#  'ACBD5': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GU-A42Q-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ACBD6': ['TCGA-G2-A2EO-01A', 'TCGA-XF-A9T8-01A', 'TCGA-ZF-A9RC-01A'],
#  'ACBD7': ['TCGA-FD-A3SS-01A', 'TCGA-FJ-A3ZE-01A', 'TCGA-UY-A78N-01A'],
#  'ACCS': ['TCGA-DK-A1A6-06A',
#   'TCGA-DK-A6B6-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A6TF-01A'],
#  'ACCSL': ['TCGA-BT-A3PK-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-YC-A8S6-01A',
#   'TCGA-ZF-A9RD-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ACD': ['TCGA-C4-A0F6-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAML-01A',
#   'TCGA-XF-AAMX-01A'],
#  'ACE': ['TCGA-BT-A20N-01A',
#   'TCGA-CU-A0YO-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-XF-AAN5-01A'],
#  'ACE2': ['TCGA-BT-A2LD-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-ZF-A9RG-01A'],
#  'ACER1': ['TCGA-DK-A1AC-01A', 'TCGA-XF-A8HD-01A', 'TCGA-XF-AAMF-01A'],
#  'ACER2': ['TCGA-ZF-AA4V-01A'],
#  'ACER3': ['TCGA-DK-A6B6-01A', 'TCGA-E5-A4TZ-01A', 'TCGA-E7-A677-01A'],
#  'ACHE': ['TCGA-2F-A9KP-01A',
#   'TCGA-C4-A0F7-01A',
#   'TCGA-CU-A0YO-01A',
#   'TCGA-GC-A3RB-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78N-01A'],
#  'ACIN1': ['TCGA-BT-A42C-01A',
#   'TCGA-CF-A27C-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-FD-A62S-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-GU-A762-01A',
#   'TCGA-GU-A764-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-GV-A40E-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-UY-A78O-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-A9SJ-01A'],
#  'ACKR2': ['TCGA-CU-A0YN-01A'],
#  'ACKR3': ['TCGA-LC-A66R-01A'],
#  'ACKR4': ['TCGA-BT-A2LB-01A', 'TCGA-DK-A6B6-01A'],
#  'ACLY': ['TCGA-4Z-AA84-01A',
#   'TCGA-CF-A5U8-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-A9SZ-01A',
#   'TCGA-YC-A89H-01A'],
#  'ACMSD': ['TCGA-FD-A62P-01A', 'TCGA-H4-A2HO-01A', 'TCGA-ZF-AA4V-01A'],
#  'ACN9': ['TCGA-DK-A1A7-01A', 'TCGA-DK-A1AB-01A', 'TCGA-K4-A6FZ-01A'],
#  'ACO1': ['TCGA-DK-AA75-01A',
#   'TCGA-GC-A3RB-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ACO2': ['TCGA-BT-A3PK-01A',
#   'TCGA-BT-A42F-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-UY-A8OC-01A',
#   'TCGA-XF-AAN5-01A',
#   'TCGA-ZF-A9R0-01A'],
#  'ACOT1': ['TCGA-YC-A89H-01A'],
#  'ACOT11': ['TCGA-BT-A2LD-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-DK-A3IS-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-GD-A2C5-01A',
#   'TCGA-XF-A9SP-01A'],
#  'ACOT12': ['TCGA-DK-AA6L-01A',
#   'TCGA-GU-A764-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-A9T8-01A'],
#  'ACOT13': ['TCGA-G2-A3VY-01A'],
#  'ACOT2': ['TCGA-DK-A3X1-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-XF-A8HD-01A'],
#  'ACOT4': ['TCGA-UY-A9PB-01A', 'TCGA-XF-A9SG-01A', 'TCGA-XF-A9T6-01A'],
#  'ACOT6': ['TCGA-BT-A0YX-01A', 'TCGA-XF-A8HG-01A'],
#  'ACOT7': ['TCGA-4Z-AA7M-01A', 'TCGA-GV-A40G-01A', 'TCGA-MV-A51V-01A'],
#  'ACOT8': ['TCGA-DK-A2I1-01A', 'TCGA-FD-A3B6-01A', 'TCGA-GU-A764-01A'],
#  'ACOT9': ['TCGA-G2-A2ES-01A', 'TCGA-KQ-A41R-01A'],
#  'ACOX1': ['TCGA-DK-A6B6-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9SJ-01A'],
#  'ACOX2': ['TCGA-BT-A42C-01A',
#   'TCGA-BT-A42E-01A',
#   'TCGA-CF-A1HR-01A',
#   'TCGA-DK-AA6S-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-K4-AAQO-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A8OD-01A',
#   'TCGA-XF-AAMJ-01A'],
#  'ACOX3': ['TCGA-DK-A3IS-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-FT-A3EE-01A',
#   'TCGA-GU-A764-01A',
#   'TCGA-YC-A89H-01A'],
#  'ACOXL': ['TCGA-DK-A1A3-01A', 'TCGA-DK-A3IN-01A'],
#  'ACP1': ['TCGA-DK-AA6U-01A', 'TCGA-MV-A51V-01A'],
#  'ACP2': ['TCGA-XF-A9SZ-01A', 'TCGA-ZF-AA4N-01A'],
#  'ACP5': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-A3IS-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-LT-A5Z6-01A',
#   'TCGA-XF-AAML-01A'],
#  'ACPL2': ['TCGA-2F-A9KT-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-AA74-01A',
#   'TCGA-GV-A3JW-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-ZF-A9R5-01A'],
#  'ACPP': ['TCGA-4Z-AA84-01A',
#   'TCGA-4Z-AA89-01A',
#   'TCGA-BL-A3JM-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-K4-A6MB-01A'],
#  'ACPT': ['TCGA-CF-A47X-01A', 'TCGA-G2-A3IE-01A', 'TCGA-GV-A3QI-01A'],
#  'ACR': ['TCGA-MV-A51V-01A'],
#  'ACRBP': ['TCGA-H4-A2HQ-01A', 'TCGA-UY-A8OB-01A'],
#  'ACRC': ['TCGA-FD-A3SJ-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-XF-A9T3-01A'],
#  'ACRV1': ['TCGA-BT-A3PK-01A'],
#  'ACSBG1': ['TCGA-4Z-AA7O-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-UY-A8OB-01A'],
#  'ACSBG2': ['TCGA-DK-A1A3-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-G2-AA3F-01A',
#   'TCGA-XF-A9SP-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RN-01A'],
#  'ACSF2': ['TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-GU-AATQ-01A',
#   'TCGA-XF-A8HH-01A',
#   'TCGA-XF-A9SK-01A',
#   'TCGA-XF-AAML-01A'],
#  'ACSF3': ['TCGA-CF-A1HS-01A',
#   'TCGA-DK-AA6Q-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A62P-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-K4-A54R-01A'],
#  'ACSL1': ['TCGA-CF-A5UA-01A', 'TCGA-E5-A4U1-01A', 'TCGA-GC-A3BM-01A'],
#  'ACSL3': ['TCGA-E7-A7DV-01A', 'TCGA-KQ-A41N-01A', 'TCGA-MV-A51V-01A'],
#  'ACSL4': ['TCGA-KQ-A41R-01A', 'TCGA-MV-A51V-01A'],
#  'ACSL5': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-GC-A4ZW-01A'],
#  'ACSL6': ['TCGA-GV-A3JX-01A'],
#  'ACSM1': ['TCGA-DK-A6AW-01A', 'TCGA-GD-A6C6-01A'],
#  'ACSM2A': ['TCGA-DK-A6AW-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ACSM2B': ['TCGA-2F-A9KT-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-XF-A9SV-01A',
#   'TCGA-ZF-AA5N-01A'],
#  'ACSM3': ['TCGA-2F-A9KR-01A', 'TCGA-G2-AA3B-01A', 'TCGA-XF-AAML-01A'],
#  'ACSM4': ['TCGA-DK-AA6W-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A9SJ-01A'],
#  'ACSM5': ['TCGA-DK-A1A5-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A3SP-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-GV-A3QG-01A',
#   'TCGA-PQ-A6FI-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A78M-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-XF-AAMX-01A'],
#  'ACSS1': ['TCGA-CF-A3MF-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-E7-A97Q-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-ZF-AA52-01A'],
#  'ACSS2': ['TCGA-DK-AA74-01A', 'TCGA-ZF-A9RM-01A'],
#  'ACSS3': ['TCGA-BT-A42E-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A3B5-01A',
#   'TCGA-GD-A3OQ-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A78N-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-ZF-A9RC-01A',
#   'TCGA-ZF-AA4V-01A',
#   'TCGA-ZF-AA54-01A'],
#  'ACTA1': ['TCGA-BT-A20J-01A',
#   'TCGA-CU-A3QU-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-XF-A9SK-01A'],
#  'ACTA2': ['TCGA-4Z-AA7W-01A',
#   'TCGA-BT-A20O-01A',
#   'TCGA-BT-A20U-01A',
#   'TCGA-CU-A3KJ-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-A9SZ-01A'],
#  'ACTB': ['TCGA-CF-A47S-01A',
#   'TCGA-DK-A1A6-06A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A6TB-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-UY-A78M-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-A9SP-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-AA56-01A'],
#  'ACTBL2': ['TCGA-GD-A6C6-01A', 'TCGA-ZF-AA4W-01A'],
#  'ACTC1': ['TCGA-FD-A3N5-01A', 'TCGA-FD-A3SM-01A'],
#  'ACTG1': ['TCGA-DK-A1A7-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-E7-A3X6-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-FJ-A3Z9-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-AAMR-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ACTG2': ['TCGA-DK-A6AW-01A'],
#  'ACTL10': ['TCGA-FD-A3SN-01A'],
#  'ACTL6A': ['TCGA-C4-A0F1-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-G2-A2EC-01A',
#   'TCGA-XF-A8HE-01A'],
#  'ACTL6B': ['TCGA-E7-A4IJ-01A',
#   'TCGA-GC-A3RD-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-XF-AAMY-01A'],
#  'ACTL7A': ['TCGA-FJ-A3ZE-01A', 'TCGA-XF-AAMG-01A'],
#  'ACTL7B': ['TCGA-BT-A20X-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ACTL8': ['TCGA-CF-A47X-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-GU-A766-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A8HG-01A'],
#  'ACTL9': ['TCGA-DK-AA6P-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-GD-A2C5-01A',
#   'TCGA-XF-AAN0-01A'],
#  'ACTN1': ['TCGA-CU-A0YO-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A8OD-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ACTN2': ['TCGA-DK-A3IK-01A',
#   'TCGA-DK-A6B5-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41P-01A',
#   'TCGA-UY-A78O-01A',
#   'TCGA-ZF-A9R2-01A'],
#  'ACTN4': ['TCGA-BT-A20J-01A',
#   'TCGA-BT-A20T-01A',
#   'TCGA-BT-A20U-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-FD-A62O-01A',
#   'TCGA-GD-A3OQ-01A',
#   'TCGA-GU-AATO-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9T8-01A'],
#  'ACTR10': ['TCGA-GD-A6C6-01A', 'TCGA-K4-A6FZ-01A', 'TCGA-YC-A89H-01A'],
#  'ACTR1A': ['TCGA-FD-A6TA-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ACTR1B': ['TCGA-FD-A3SS-01A', 'TCGA-ZF-AA54-01A'],
#  'ACTR2': ['TCGA-E7-A541-01A', 'TCGA-KQ-A41R-01A'],
#  'ACTR3': ['TCGA-DK-A2I6-01A', 'TCGA-E7-A85H-01A'],
#  'ACTR3B': ['TCGA-GC-A6I1-01A',
#   'TCGA-KQ-A41S-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-ZF-AA52-01A'],
#  'ACTR3C': ['TCGA-4Z-AA7Q-01A'],
#  'ACTR5': ['TCGA-FD-A62O-01A', 'TCGA-K4-A6FZ-01A'],
#  'ACTR6': ['TCGA-DK-A3WW-01A', 'TCGA-DK-AA6S-01A'],
#  'ACTR8': ['TCGA-DK-A3IS-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A3X6-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-LT-A5Z6-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ACTRT1': ['TCGA-DK-AA6U-01A', 'TCGA-GU-A766-01A', 'TCGA-MV-A51V-01A'],
#  'ACTRT2': ['TCGA-DK-A6AW-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ACTRT3': ['TCGA-BT-A20N-01A', 'TCGA-GV-A3JV-01A', 'TCGA-XF-A9T0-01A'],
#  'ACVR1': ['TCGA-DK-A6AW-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-UY-A78O-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-ZF-A9R4-01A'],
#  'ACVR1B': ['TCGA-K4-A3WS-01A', 'TCGA-ZF-A9R0-01A'],
#  'ACVR1C': ['TCGA-FJ-A3Z7-01A', 'TCGA-SY-A9G5-01A'],
#  'ACVR2A': ['TCGA-DK-A3IS-01A'],
#  'ACVR2B': ['TCGA-4Z-AA7W-01A', 'TCGA-MV-A51V-01A'],
#  'ACVRL1': ['TCGA-C4-A0F0-01A',
#   'TCGA-CF-A47V-01A',
#   'TCGA-DK-A1AF-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-S5-A6DX-01A'],
#  'ACY1': ['TCGA-DK-A6AW-01A', 'TCGA-GV-A3JZ-01A', 'TCGA-XF-AAN3-01A'],
#  'ACY3': ['TCGA-4Z-AA84-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-GC-A3WC-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-PQ-A6FN-01A',
#   'TCGA-XF-A8HF-01A'],
#  'ADA': ['TCGA-G2-A3VY-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-YF-AA3L-01A',
#   'TCGA-ZF-A9RF-01A'],
#  'ADAD1': ['TCGA-4Z-AA84-01A', 'TCGA-DK-A6AW-01A', 'TCGA-GU-A762-01A'],
#  'ADAD2': ['TCGA-KQ-A41N-01A'],
#  'ADAL': ['TCGA-DK-A6AW-01A', 'TCGA-XF-A8HF-01A'],
#  'ADAM10': ['TCGA-4Z-AA7M-01A',
#   'TCGA-CF-A27C-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-UY-A78M-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-AAMJ-01A',
#   'TCGA-ZF-AA54-01A'],
#  'ADAM11': ['TCGA-4Z-AA7W-01A',
#   'TCGA-BT-A42B-01A',
#   'TCGA-CF-A9FH-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ADAM12': ['TCGA-4Z-AA7M-01A',
#   'TCGA-BT-A20N-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-S5-A6DX-01A'],
#  'ADAM15': ['TCGA-CF-A9FF-01A',
#   'TCGA-DK-A1AB-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-E7-A3Y1-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FT-A61P-01A',
#   'TCGA-GV-A3QI-01A'],
#  'ADAM17': ['TCGA-4Z-AA7O-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RD-01A'],
#  'ADAM18': ['TCGA-DK-A3WW-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-XF-AAMF-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ADAM19': ['TCGA-4Z-AA84-01A',
#   'TCGA-DK-A1A6-06A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-ZF-AA54-01A'],
#  'ADAM2': ['TCGA-BT-A20R-01A',
#   'TCGA-CF-A1HS-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A6TE-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-UY-A9PA-01A',
#   'TCGA-ZF-A9RF-01A'],
#  'ADAM20': ['TCGA-FD-A5BX-01A', 'TCGA-ZF-A9R2-01A'],
#  'ADAM21': ['TCGA-E7-A7XN-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-ZF-AA56-01A'],
#  'ADAM22': ['TCGA-DK-A1A6-06A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FT-A3EE-01A',
#   'TCGA-FT-A61P-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9SI-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-ZF-A9RG-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ADAM23': ['TCGA-BT-A20R-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-XF-A9SP-01A'],
#  'ADAM28': ['TCGA-4Z-AA82-01A', 'TCGA-ZF-A9RC-01A'],
#  'ADAM29': ['TCGA-CU-A3KJ-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-DK-A1AG-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GC-A3OO-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-AAMX-01A',
#   'TCGA-YF-AA3L-01A',
#   'TCGA-ZF-A9RL-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ADAM30': ['TCGA-DK-A1A6-06A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A4IJ-01A',
#   'TCGA-E7-A519-01A',
#   'TCGA-FD-A3B3-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FD-A6TI-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-HQ-A5ND-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ADAM32': ['TCGA-DK-A3IL-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-LC-A66R-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ADAM33': ['TCGA-DK-A1AC-01A', 'TCGA-GC-A3RC-01A'],
#  'ADAM7': ['TCGA-CF-A47Y-01A',
#   'TCGA-FD-A6TI-01A',
#   'TCGA-GU-AATO-01A',
#   'TCGA-H4-A2HQ-01A'],
#  'ADAM8': ['TCGA-2F-A9KO-01A', 'TCGA-4Z-AA7W-01A', 'TCGA-GU-A42P-01A'],
#  'ADAM9': ['TCGA-BT-A20N-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-YC-A89H-01A'],
#  'ADAMDEC1': ['TCGA-GU-A42P-01A'],
#  'ADAMTS1': ['TCGA-XF-A9ST-01A', 'TCGA-XF-A9T0-01A'],
#  'ADAMTS10': ['TCGA-C4-A0F6-01A',
#   'TCGA-DK-A3IS-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-E7-A3X6-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-G2-A2EC-01A',
#   'TCGA-G2-A2EF-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-A9SW-01A',
#   'TCGA-XF-AAMZ-01A'],
#  'ADAMTS12': ['TCGA-4Z-AA80-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-BT-A20O-01A',
#   'TCGA-C4-A0F6-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A1A7-01A',
#   'TCGA-DK-A3IM-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-E7-A3Y1-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-G2-A2EC-01A',
#   'TCGA-G2-A3IB-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-ZF-A9R1-01A',
#   'TCGA-ZF-A9RC-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ADAMTS13': ['TCGA-2F-A9KT-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A6TF-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-XF-A9ST-01A'],
#  'ADAMTS14': ['TCGA-BL-A0C8-01A',
#   'TCGA-BT-A20J-01A',
#   'TCGA-BT-A42E-01A',
#   'TCGA-CF-A9FF-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-E7-A3Y1-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-A9ST-01A'],
#  'ADAMTS15': ['TCGA-4Z-AA84-01A',
#   'TCGA-CF-A8HX-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-K4-A83P-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAMF-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ADAMTS16': ['TCGA-BL-A5ZZ-01A',
#   'TCGA-BT-A20J-01A',
#   'TCGA-BT-A42F-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-FD-A3B3-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-GU-A42R-01A',
#   'TCGA-GV-A3JZ-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-UY-A78L-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ADAMTS17': ['TCGA-GU-AATQ-01A', 'TCGA-LC-A66R-01A', 'TCGA-ZF-AA4W-01A'],
#  'ADAMTS18': ['TCGA-5N-A9KM-01A',
#   'TCGA-CF-A9FH-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6P-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-G2-A2EK-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-GV-A40E-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-R3-A69X-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-ZF-A9R3-01A'],
#  'ADAMTS19': ['TCGA-2F-A9KO-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A5BY-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A9PD-01A',
#   'TCGA-YC-A89H-01A'],
#  'ADAMTS2': ['TCGA-BT-A3PK-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-FD-A5C1-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-K4-A83P-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ADAMTS20': ['TCGA-CF-A1HR-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-FD-A6TH-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-UY-A78L-01A',
#   'TCGA-UY-A9PD-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-ZF-A9R4-01A'],
#  'ADAMTS3': ['TCGA-BT-A20R-01A',
#   'TCGA-CF-A1HS-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-FD-A3SM-01A',
#   'TCGA-FD-A62S-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-GU-AATO-01A',
#   'TCGA-UY-A8OD-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-AAMZ-01A'],
#  'ADAMTS4': ['TCGA-DK-AA71-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-FD-A62O-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GU-A767-01A',
#   'TCGA-XF-A9SZ-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ADAMTS5': ['TCGA-BT-A3PK-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-G2-A2EF-01A',
#   'TCGA-GC-A6I3-01A',
#   'TCGA-GD-A3OS-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-UY-A8OB-01A',
#   'TCGA-UY-A9PB-01A'],
#  'ADAMTS6': ['TCGA-4Z-AA7R-01A',
#   'TCGA-BT-A20N-01A',
#   'TCGA-E7-A3Y1-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-G2-AA3D-01A',
#   'TCGA-GV-A3JW-01A',
#   'TCGA-K4-A6FZ-01A'],
#  'ADAMTS7': ['TCGA-E7-A677-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GV-A3JV-01A',
#   'TCGA-XF-A9T8-01A'],
#  'ADAMTS8': ['TCGA-2F-A9KR-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E5-A2PC-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-XF-AAN4-01A'],
#  'ADAMTS9': ['TCGA-4Z-AA7O-01A',
#   'TCGA-4Z-AA80-01A',
#   'TCGA-4Z-AA81-01A',
#   'TCGA-CF-A1HS-01A',
#   'TCGA-DK-A2HX-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A3NA-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-GC-A3YS-01A',
#   'TCGA-HQ-A2OE-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-UY-A78N-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-XF-AAMT-01A',
#   'TCGA-XF-AAMY-01A',
#   'TCGA-XF-AAN0-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-AA4U-01A'],
#  'ADAMTSL1': ['TCGA-4Z-AA7S-01A',
#   'TCGA-4Z-AA82-01A',
#   'TCGA-BT-A42E-01A',
#   'TCGA-C4-A0EZ-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6B2-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-K4-A5RH-01A',
#   'TCGA-PQ-A6FI-01A',
#   'TCGA-UY-A9PA-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-A9RM-01A',
#   'TCGA-ZF-A9RN-01A'],
#  'ADAMTSL2': ['TCGA-BT-A42E-01A', 'TCGA-C4-A0EZ-01A', 'TCGA-XF-A9T6-01A'],
#  'ADAMTSL3': ['TCGA-BT-A20N-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-BT-A42C-01A',
#   'TCGA-CF-A3MH-01A',
#   'TCGA-DK-A1A6-06A',
#   'TCGA-DK-A6B6-01A',
#   'TCGA-DK-AA6L-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FD-A5BV-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-GD-A2C5-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-AAN5-01A',
#   'TCGA-YF-AA3L-01A'],
#  'ADAMTSL4': ['TCGA-4Z-AA7M-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-FD-A3SL-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9T5-01A'],
#  'ADAMTSL5': ['TCGA-FD-A3SO-01A', 'TCGA-XF-A9T0-01A'],
#  'ADAP1': ['TCGA-FD-A6TG-01A', 'TCGA-XF-A9T5-01A'],
#  'ADAP2': ['TCGA-GU-A763-01A'],
#  'ADAR': ['TCGA-4Z-AA81-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-FD-A5BU-01A',
#   'TCGA-FT-A61P-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-K4-AAQO-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A9SJ-01A',
#   'TCGA-XF-AAN0-01A',
#   'TCGA-ZF-A9R4-01A'],
#  'ADARB1': ['TCGA-DK-A3X1-01A', 'TCGA-DK-AA6R-01A'],
#  'ADARB2': ['TCGA-5N-A9KM-01A',
#   'TCGA-BL-A5ZZ-01A',
#   'TCGA-BT-A2LD-01A',
#   'TCGA-CF-A3MG-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-K4-A5RI-01A',
#   'TCGA-XF-AAMH-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ADAT1': ['TCGA-4Z-AA84-01A',
#   'TCGA-DK-A1AF-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HF-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ADAT2': ['TCGA-DK-A3WX-01A', 'TCGA-GV-A6ZA-01A'],
#  'ADC': ['TCGA-2F-A9KT-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-XF-A9SW-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ADCK1': ['TCGA-E7-A678-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-YC-A89H-01A'],
#  'ADCK2': ['TCGA-DK-A3X1-01A',
#   'TCGA-E7-A6ME-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-ZF-AA53-01A'],
#  'ADCK3': ['TCGA-BT-A20O-01A',
#   'TCGA-CF-A1HR-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-XF-AAN2-01A'],
#  'ADCK4': ['TCGA-BT-A20J-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-KQ-A41Q-01A'],
#  'ADCK5': ['TCGA-DK-A1AC-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-UY-A9PH-01A'],
#  'ADCY1': ['TCGA-DK-A2I1-01A',
#   'TCGA-FJ-A3ZE-01A',
#   'TCGA-GC-A6I1-01A',
#   'TCGA-GV-A3QF-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A9PE-01A'],
#  'ADCY10': ['TCGA-4Z-AA7W-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A3N5-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FD-A5BT-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-ZF-AA54-01A'],
#  'ADCY2': ['TCGA-BT-A0YX-01A',
#   'TCGA-BT-A20R-01A',
#   'TCGA-BT-A3PH-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-DK-A1A7-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6M-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-FD-A6TF-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-LT-A5Z6-01A',
#   'TCGA-SY-A9G0-01A',
#   'TCGA-UY-A9PA-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ADCY3': ['TCGA-DK-A3IS-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-XF-A9SI-01A'],
#  'ADCY4': ['TCGA-C4-A0EZ-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-XF-AAMQ-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RN-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ADCY5': ['TCGA-4Z-AA81-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-CF-A8HY-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-DK-AA6T-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A43U-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ADCY6': ['TCGA-BT-A0YX-01A',
#   'TCGA-BT-A2LD-01A',
#   'TCGA-CU-A5W6-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-AA6T-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-GU-A764-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-ZF-A9RD-01A'],
#  'ADCY7': ['TCGA-4Z-AA7Q-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-KQ-A41R-01A'],
#  'ADCY8': ['TCGA-4Z-AA84-01A',
#   'TCGA-C4-A0F0-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA6L-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-FD-A5BR-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-FD-A6TD-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-GV-A40G-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-A9SV-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAML-01A'],
#  'ADCY9': ['TCGA-BT-A3PH-01A',
#   'TCGA-CF-A1HR-01A',
#   'TCGA-CF-A47S-01A',
#   'TCGA-CU-A72E-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A3SP-01A',
#   'TCGA-ZF-A9R4-01A'],
#  'ADCYAP1R1': ['TCGA-2F-A9KO-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-FD-A3B6-01A',
#   'TCGA-FJ-A3Z9-01A',
#   'TCGA-YF-AA3M-01A'],
#  'ADD1': ['TCGA-4Z-AA80-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-XF-AAMG-01A'],
#  'ADD2': ['TCGA-4Z-AA87-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-E7-A5KF-01A',
#   'TCGA-FD-A3SQ-01A',
#   'TCGA-K4-A3WV-01A',
#   'TCGA-UY-A78L-01A',
#   'TCGA-YF-AA3L-01A'],
#  'ADD3': ['TCGA-4Z-AA7Q-01A',
#   'TCGA-DK-A2HX-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9SH-01A',
#   'TCGA-XF-AAMX-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ADH1A': ['TCGA-DK-A2I4-01A',
#   'TCGA-DK-A6B1-01A',
#   'TCGA-DK-AA77-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ADH1B': ['TCGA-DK-A1A5-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-XF-A8HF-01A'],
#  'ADH1C': ['TCGA-DK-A6AW-01A',
#   'TCGA-KQ-A41S-01A',
#   'TCGA-XF-A8HI-01A',
#   'TCGA-ZF-A9R0-01A'],
#  'ADH4': ['TCGA-E7-A677-01A', 'TCGA-XF-AAN5-01A'],
#  'ADH5': ['TCGA-KQ-A41N-01A', 'TCGA-XF-A9T0-01A'],
#  'ADH6': ['TCGA-4Z-AA7R-01A',
#   'TCGA-CF-A3MH-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-E7-A5KF-01A',
#   'TCGA-FD-A6TI-01A',
#   'TCGA-FJ-A3Z7-01A',
#   'TCGA-K4-A6MB-01A'],
#  'ADH7': ['TCGA-4Z-AA7M-01A',
#   'TCGA-4Z-AA7W-01A',
#   'TCGA-GU-A762-01A',
# ...
#  'ARHGAP9': ['TCGA-4Z-AA7O-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FD-A6TE-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-A9SM-01A',
#   'TCGA-XF-A9SY-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ARHGDIA': ['TCGA-LC-A66R-01A', 'TCGA-UY-A9PF-01A'],
#  'ARHGDIB': ['TCGA-E7-A6ME-01A'],
#  'ARHGEF1': ['TCGA-BL-A13J-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ARHGEF10': ['TCGA-4Z-AA7Q-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-S5-AA26-01A'],
#  'ARHGEF10L': ['TCGA-DK-A3IQ-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GV-A3QH-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ARHGEF11': ['TCGA-4Z-AA7W-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GU-A766-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A78N-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAMZ-01A',
#   'TCGA-ZF-A9RF-01A',
#   'TCGA-ZF-AA4N-01A'],
#  'ARHGEF12': ['TCGA-DK-A2I1-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A8O7-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-GD-A6C6-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-LC-A66R-01A',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-AAN1-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-AA4V-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ARHGEF15': ['TCGA-4Z-AA84-01A',
#   'TCGA-5N-A9KI-01A',
#   'TCGA-CU-A0YO-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-E7-A97Q-01A',
#   'TCGA-FD-A3SS-01A',
#   'TCGA-YC-A89H-01A'],
#  'ARHGEF16': ['TCGA-4Z-AA7W-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-BT-A42F-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-LT-A5Z6-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-XF-A9SI-01A'],
#  'ARHGEF17': ['TCGA-4Z-AA80-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-FD-A3SJ-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GU-AATQ-01A'],
#  'ARHGEF18': ['TCGA-CU-A72E-01A',
#   'TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-FD-A62P-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-UY-A9PB-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ARHGEF19': ['TCGA-DK-A3WW-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-GC-A3OO-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-XF-AAMZ-01A'],
#  'ARHGEF2': ['TCGA-DK-A3IS-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-FD-A5BX-01A',
#   'TCGA-GU-A42R-01A',
#   'TCGA-PQ-A6FI-01A',
#   'TCGA-XF-A9T3-01A',
#   'TCGA-ZF-A9R1-01A'],
#  'ARHGEF25': ['TCGA-2F-A9KP-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-GU-A42Q-01A',
#   'TCGA-K4-A4AC-01A',
#   'TCGA-S5-A6DX-01A'],
#  'ARHGEF26': ['TCGA-BT-A20Q-01A',
#   'TCGA-BT-A2LA-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-XF-A8HF-01A'],
#  'ARHGEF28': ['TCGA-4Z-AA84-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-E7-A6MF-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-XF-A9T4-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ARHGEF3': ['TCGA-4Z-AA87-01A',
#   'TCGA-BT-A20Q-01A',
#   'TCGA-BT-A42B-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-E7-A677-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-UY-A78K-01A'],
#  'ARHGEF35': ['TCGA-DK-A3IS-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-E7-A3X6-01A',
#   'TCGA-E7-A7DV-01A',
#   'TCGA-FD-A62P-01A'],
#  'ARHGEF37': ['TCGA-4Z-AA80-01A',
#   'TCGA-FD-A3SL-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-YC-A89H-01A'],
#  'ARHGEF4': ['TCGA-DK-A1AF-01A', 'TCGA-GC-A3WC-01A', 'TCGA-S5-A6DX-01A'],
#  'ARHGEF40': ['TCGA-BT-A42E-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-E5-A4U1-01A',
#   'TCGA-FD-A6TF-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-KQ-A41R-01A'],
#  'ARHGEF5': ['TCGA-BL-A13J-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-GC-A3BM-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ARHGEF6': ['TCGA-4Z-AA89-01A',
#   'TCGA-5N-A9KM-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-G2-AA3C-01A',
#   'TCGA-UY-A78L-01A'],
#  'ARHGEF7': ['TCGA-DK-A3IS-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-G2-A2EF-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GV-A3QF-01A',
#   'TCGA-K4-A6FZ-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A8OC-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-YF-AA3L-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ARHGEF9': ['TCGA-4Z-AA84-01A', 'TCGA-FJ-A3Z7-01A', 'TCGA-GC-A3RC-01A'],
#  'ARID1A': ['TCGA-2F-A9KO-01A',
#   'TCGA-2F-A9KP-01A',
#   'TCGA-2F-A9KW-01A',
#   'TCGA-4Z-AA7O-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-5N-A9KI-01A',
#   'TCGA-BL-A0C8-01A',
#   'TCGA-BL-A13I-01A',
#   'TCGA-BL-A3JM-01A',
#   'TCGA-BL-A5ZZ-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-BT-A20Q-01A',
#   'TCGA-BT-A20R-01A',
#   'TCGA-BT-A2LD-01A',
#   'TCGA-BT-A3PH-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-CF-A1HR-01A',
#   'TCGA-CF-A3MG-01A',
#   'TCGA-CU-A0YO-01A',
#   'TCGA-CU-A3KJ-01A',
#   'TCGA-CU-A5W6-01A',
#   'TCGA-DK-A1AD-01A',
#   'TCGA-DK-A1AE-01A',
#   'TCGA-DK-A2HX-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-DK-A3IM-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-DK-A3IU-01A',
#   'TCGA-DK-A3X2-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-A6B2-01A',
#   'TCGA-DK-A6B5-01A',
#   'TCGA-DK-AA6P-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-DK-AA6W-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-E7-A4XJ-01A',
#   'TCGA-E7-A519-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-E7-A7DU-01A',
#   'TCGA-E7-A85H-01A',
#   'TCGA-FD-A3B3-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FD-A3SP-01A',
#   'TCGA-FD-A3SR-01A',
#   'TCGA-FD-A43N-01A',
#   'TCGA-FD-A5C1-01A',
#   'TCGA-FD-A62O-01A',
#   'TCGA-FD-A62P-01A',
#   'TCGA-FD-A6TG-01A',
#   'TCGA-FD-A6TI-01A',
#   'TCGA-FD-A6TK-01A',
#   'TCGA-FJ-A3Z9-01A',
#   'TCGA-FJ-A3ZF-01A',
#   'TCGA-FJ-A871-01A',
#   'TCGA-G2-A2EK-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-G2-AA3D-01A',
#   'TCGA-G2-AA3F-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-GC-A4ZW-01A',
#   'TCGA-GD-A2C5-01A',
#   'TCGA-GD-A3OQ-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-GU-A42P-01A',
#   'TCGA-GU-A42R-01A',
#   'TCGA-GU-A766-01A',
#   'TCGA-GV-A3JV-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-GV-A6ZA-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-K4-A3WV-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-K4-A83P-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-LC-A66R-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9SP-01A',
#   'TCGA-XF-A9SW-01A',
#   'TCGA-XF-A9SZ-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-XF-A9T2-01A',
#   'TCGA-XF-A9T5-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAML-01A',
#   'TCGA-XF-AAN0-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-YC-A8S6-01A',
#   'TCGA-YF-AA3M-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-A9R9-01A',
#   'TCGA-ZF-A9RC-01A',
#   'TCGA-ZF-A9RF-01A',
#   'TCGA-ZF-AA4X-01A',
#   'TCGA-ZF-AA51-01A',
#   'TCGA-ZF-AA5N-01A'],
#  'ARID1B': ['TCGA-2F-A9KO-01A',
#   'TCGA-4Z-AA80-01A',
#   'TCGA-BL-A13I-01A',
#   'TCGA-BT-A3PH-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA74-01A',
#   'TCGA-E7-A4IJ-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-GU-AATO-01A',
#   'TCGA-GU-AATP-01A',
#   'TCGA-KQ-A41P-01A',
#   'TCGA-XF-A8HD-01A',
#   'TCGA-XF-A9SK-01A',
#   'TCGA-ZF-A9R4-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA4V-01A',
#   'TCGA-ZF-AA51-01A',
#   'TCGA-ZF-AA5N-01A'],
#  'ARID2': ['TCGA-2F-A9KP-01A',
#   'TCGA-4Z-AA83-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-CF-A3MI-01A',
#   'TCGA-CF-A9FF-01A',
#   'TCGA-CU-A3YL-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-DK-A2I2-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A6AV-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-DK-AA76-01A',
#   'TCGA-FD-A3N5-01A',
#   'TCGA-FD-A3SJ-01A',
#   'TCGA-FD-A3SN-01A',
#   'TCGA-FD-A3SR-01A',
#   'TCGA-FD-A6TA-01A',
#   'TCGA-FD-A6TB-01A',
#   'TCGA-G2-A2EO-01A',
#   'TCGA-GC-A3WC-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-GV-A40G-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-K4-A4AC-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41P-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-UY-A9PF-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-A8HH-01A',
#   'TCGA-XF-A9SZ-01A'],
#  'ARID3A': ['TCGA-FD-A43X-01A'],
#  'ARID3B': ['TCGA-BT-A3PJ-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-GC-A3RC-01A',
#   'TCGA-XF-A9SI-01A'],
#  'ARID3C': ['TCGA-BT-A2LB-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-S5-A6DX-01A'],
#  'ARID4A': ['TCGA-4Z-AA81-01A',
#   'TCGA-5N-A9KM-01A',
#   'TCGA-BT-A0YX-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-DK-A3IQ-01A',
#   'TCGA-DK-A3IT-01A',
#   'TCGA-E5-A4TZ-01A',
#   'TCGA-G2-A2EL-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GU-A42R-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78O-01A',
#   'TCGA-XF-A9T8-01A',
#   'TCGA-XF-AAML-01A',
#   'TCGA-ZF-AA4R-01A'],
#  'ARID4B': ['TCGA-BT-A0YX-01A',
#   'TCGA-BT-A2LB-01A',
#   'TCGA-CU-A3QU-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-AA6R-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-GV-A3JZ-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-YC-A9TC-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ARID5A': ['TCGA-4Z-AA7W-01A',
#   'TCGA-4Z-AA80-01A',
#   'TCGA-DK-A1A3-01A',
#   'TCGA-DK-A1A5-01A',
#   'TCGA-FD-A43P-01A',
#   'TCGA-KQ-A41R-01A'],
#  'ARID5B': ['TCGA-4Z-AA84-01A',
#   'TCGA-BT-A20O-01A',
#   'TCGA-BT-A3PK-01A',
#   'TCGA-DK-A1AB-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-YC-A89H-01A'],
#  'ARIH1': ['TCGA-DK-AA6U-01A',
#   'TCGA-E7-A7XN-01A',
#   'TCGA-S5-A6DX-01A',
#   'TCGA-XF-A8HB-01A'],
#  'ARIH2': ['TCGA-4Z-AA81-01A',
#   'TCGA-DK-AA6L-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-GC-A3I6-01A',
#   'TCGA-GV-A3QK-01B',
#   'TCGA-K4-A5RI-01A',
#   'TCGA-MV-A51V-01A',
#   'TCGA-UY-A9PE-01A',
#   'TCGA-XF-AAN2-01A',
#   'TCGA-ZF-A9RL-01A'],
#  'ARIH2OS': ['TCGA-C4-A0F1-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A4IJ-01A',
#   'TCGA-FD-A3N6-01A',
#   'TCGA-ZF-A9R9-01A'],
#  'ARL11': ['TCGA-XF-A9SG-01A'],
#  'ARL13A': ['TCGA-K4-A4AC-01A', 'TCGA-MV-A51V-01A', 'TCGA-XF-A9SV-01A'],
#  'ARL13B': ['TCGA-BT-A20Q-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-G2-AA3F-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-K4-A83P-01A'],
#  'ARL14': ['TCGA-DK-A1AC-01A',
#   'TCGA-E7-A4IJ-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-KQ-A41R-01A'],
#  'ARL14EP': ['TCGA-FD-A6TC-01A'],
#  'ARL15': ['TCGA-DK-A6AW-01A', 'TCGA-E7-A7XN-01A', 'TCGA-XF-AAN2-01A'],
#  'ARL16': ['TCGA-DK-A3IK-01A',
#   'TCGA-DK-A6AV-01A',
#   'TCGA-K4-A5RJ-01A',
#   'TCGA-K4-AAQO-01A'],
#  'ARL2BP': ['TCGA-BT-A0YX-01A'],
#  'ARL3': ['TCGA-CU-A3YL-01A'],
#  'ARL4A': ['TCGA-DK-A1AC-01A',
#   'TCGA-G2-A2ES-01A',
#   'TCGA-GU-A762-01A',
#   'TCGA-XF-A9SM-01A'],
#  'ARL4C': ['TCGA-UY-A9PF-01A', 'TCGA-XF-A9T5-01A'],
#  'ARL4D': ['TCGA-XF-AAN0-01A'],
#  'ARL5B': ['TCGA-DK-A6AW-01A', 'TCGA-E7-A519-01A', 'TCGA-XF-A9SM-01A'],
#  'ARL6': ['TCGA-ZF-AA5P-01A'],
#  'ARL6IP1': ['TCGA-FD-A3N5-01A'],
#  'ARL6IP4': ['TCGA-FD-A6TC-01A'],
#  'ARL6IP5': ['TCGA-DK-A6AW-01A', 'TCGA-E7-A8O8-01A'],
#  'ARL6IP6': ['TCGA-CU-A3YL-01A', 'TCGA-FD-A3SO-01A'],
#  'ARL8A': ['TCGA-DK-AA76-01A', 'TCGA-G2-AA3D-01A', 'TCGA-XF-A9SZ-01A'],
#  'ARL8B': ['TCGA-XF-A8HE-01A', 'TCGA-XF-A9ST-01A', 'TCGA-ZF-A9R9-01A'],
#  'ARL9': ['TCGA-DK-A6AW-01A'],
#  'ARMC1': ['TCGA-YF-AA3M-01A'],
#  'ARMC10': ['TCGA-E7-A5KE-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A9PH-01A'],
#  'ARMC12': ['TCGA-DK-A2HX-01A', 'TCGA-DK-A3IK-01A', 'TCGA-HQ-A5NE-01A'],
#  'ARMC2': ['TCGA-BT-A2LA-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-FD-A62N-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-XF-A9SY-01A'],
#  'ARMC3': ['TCGA-BT-A20Q-01A',
#   'TCGA-BT-A42C-01A',
#   'TCGA-CU-A0YR-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FT-A3EE-01A',
#   'TCGA-FT-A61P-01A',
#   'TCGA-H4-A2HO-01A',
#   'TCGA-XF-A8HF-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAN2-01A'],
#  'ARMC4': ['TCGA-BT-A0YX-01A',
#   'TCGA-BT-A3PJ-01A',
#   'TCGA-DK-A1AB-01A',
#   'TCGA-DK-A2I1-01A',
#   'TCGA-G2-AA3B-01A',
#   'TCGA-GV-A3JX-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-ZF-A9R5-01A',
#   'TCGA-ZF-AA51-01A'],
#  'ARMC5': ['TCGA-4Z-AA7M-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-AA6U-01A',
#   'TCGA-GV-A3QI-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-K4-AAQO-01A'],
#  'ARMC6': ['TCGA-FD-A3SS-01A',
#   'TCGA-G2-AA3D-01A',
#   'TCGA-HQ-A5NE-01A',
#   'TCGA-UY-A9PH-01A',
#   'TCGA-XF-AAML-01A'],
#  'ARMC7': ['TCGA-DK-A3IU-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-G2-A2EJ-01A',
#   'TCGA-HQ-A5NE-01A'],
#  'ARMC8': ['TCGA-DK-A6B2-01A',
#   'TCGA-E7-A541-01A',
#   'TCGA-FJ-A3Z7-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R1-01A',
#   'TCGA-ZF-AA4W-01A'],
#  'ARMC9': ['TCGA-BT-A0YX-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-ZF-AA4X-01A'],
#  'ARMCX1': ['TCGA-BT-A20V-01A',
#   'TCGA-DK-A3IK-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-XF-AAN2-01A'],
#  'ARMCX2': ['TCGA-4Z-AA80-01A',
#   'TCGA-CF-A47X-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-FD-A5C1-01A',
#   'TCGA-XF-A9SZ-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ARMCX3': ['TCGA-5N-A9KI-01A', 'TCGA-DK-AA6U-01A'],
#  'ARMCX5': ['TCGA-DK-A3IN-01A',
#   'TCGA-DK-AA6L-01A',
#   'TCGA-GV-A3JZ-01A',
#   'TCGA-XF-AAN4-01A'],
#  'ARMCX6': ['TCGA-4Z-AA7W-01A',
#   'TCGA-4Z-AA87-01A',
#   'TCGA-FD-A3B7-01A',
#   'TCGA-XF-A9SP-01A'],
#  'ARNT': ['TCGA-4Z-AA7Y-01A',
#   'TCGA-DK-A1A6-06A',
#   'TCGA-E7-A8O7-01A',
#   'TCGA-E7-A97P-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FD-A5BT-01A',
#   'TCGA-KQ-A41Q-01A',
#   'TCGA-XF-A9SH-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-ZF-A9RF-01A'],
#  'ARNT2': ['TCGA-DK-A1AC-01A',
#   'TCGA-DK-A2I6-01A',
#   'TCGA-E7-A5KE-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-FD-A6TC-01A',
#   'TCGA-HQ-A2OF-01A',
#   'TCGA-R3-A69X-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ARNTL': ['TCGA-CU-A72E-01A',
#   'TCGA-DK-A6B6-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-UY-A9PD-01A'],
#  'ARNTL2': ['TCGA-4Z-AA7W-01A',
#   'TCGA-DK-A1AB-01A',
#   'TCGA-DK-A2I4-01A',
#   'TCGA-DK-A3IN-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-AA71-01A'],
#  'ARPC1A': ['TCGA-CF-A47Y-01A',
#   'TCGA-DK-A6B6-01A',
#   'TCGA-GU-A767-01A',
#   'TCGA-MV-A51V-01A'],
#  'ARPC1B': ['TCGA-S5-A6DX-01A'],
#  'ARPC2': ['TCGA-BT-A3PK-01A',
#   'TCGA-DK-A3WW-01A',
#   'TCGA-DK-A3X1-01A',
#   'TCGA-XF-A9T6-01A',
#   'TCGA-XF-AAN5-01A'],
#  'ARPC4': ['TCGA-DK-A3WW-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA75-01A',
#   'TCGA-K4-A3WS-01A',
#   'TCGA-ZF-A9R7-01A'],
#  'ARPC5': ['TCGA-4Z-AA7M-01A',
#   'TCGA-4Z-AA84-01A',
#   'TCGA-FD-A3SO-01A',
#   'TCGA-ZF-AA4V-01A'],
#  'ARPP19': ['TCGA-FD-A43Y-01A', 'TCGA-G2-A2EJ-01A', 'TCGA-ZF-AA4V-01A'],
#  'ARPP21': ['TCGA-BL-A3JM-01A',
#   'TCGA-BT-A20N-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-DK-AA74-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-A9R7-01A',
#   'TCGA-ZF-AA56-01A'],
#  'ARR3': ['TCGA-DK-AA6S-01A', 'TCGA-E7-A541-01A'],
#  'ARRB1': ['TCGA-FD-A62P-01A',
#   'TCGA-H4-A2HQ-01A',
#   'TCGA-XF-A8HE-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-A9T8-01A'],
#  'ARRB2': ['TCGA-4Z-AA7Y-01A', 'TCGA-KQ-A41O-01A', 'TCGA-XF-A9SY-01A'],
#  'ARRDC1': ['TCGA-LT-A5Z6-01A', 'TCGA-XF-A8HD-01A'],
#  'ARRDC2': ['TCGA-4Z-AA7W-01A'],
#  'ARRDC3': ['TCGA-BT-A20N-01A',
#   'TCGA-DK-A6B6-01A',
#   'TCGA-FD-A3NA-01A',
#   'TCGA-G2-A3IE-01A',
#   'TCGA-KQ-A41N-01A',
#   'TCGA-UY-A78K-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-XF-AAMG-01A',
#   'TCGA-XF-AAML-01A'],
#  'ARRDC4': ['TCGA-ZF-AA58-01A'],
#  'ARRDC5': ['TCGA-4Z-AA7R-01A', 'TCGA-DK-A6AW-01A'],
#  'ARSA': ['TCGA-4Z-AA82-01A', 'TCGA-DK-A3WW-01A', 'TCGA-XF-A8HG-01A'],
#  'ARSB': ['TCGA-4Z-AA80-01A',
#   'TCGA-DK-AA71-01A',
#   'TCGA-G2-AA3D-01A',
#   'TCGA-GD-A3OP-01A',
#   'TCGA-KQ-A41R-01A',
#   'TCGA-SY-A9G5-01A',
#   'TCGA-ZF-A9RD-01A'],
#  'ARSD': ['TCGA-E7-A85H-01A',
#   'TCGA-FD-A62S-01A',
#   'TCGA-FD-A6TE-01A',
#   'TCGA-GC-A3RD-01A',
#   'TCGA-XF-A9SZ-01A'],
#  'ARSE': ['TCGA-BT-A2LA-01A', 'TCGA-K4-A5RJ-01A', 'TCGA-KQ-A41N-01A'],
#  'ARSF': ['TCGA-BT-A20T-01A', 'TCGA-DK-A3X1-01A', 'TCGA-XF-AAMR-01A'],
#  'ARSG': ['TCGA-BL-A0C8-01A',
#   'TCGA-E7-A6MD-01A',
#   'TCGA-K4-A6MB-01A',
#   'TCGA-XF-AAMQ-01A',
#   'TCGA-ZF-AA58-01A'],
#  'ARSH': ['TCGA-DK-A3X1-01A',
#   'TCGA-DK-AA74-01A',
#   'TCGA-FD-A43X-01A',
#   'TCGA-XF-A8HC-01A',
#   'TCGA-XF-AAMJ-01A'],
#  'ARSI': ['TCGA-GD-A3OP-01A', 'TCGA-GV-A3JZ-01A'],
#  'ARSJ': ['TCGA-C4-A0F6-01A',
#   'TCGA-GD-A76B-01A',
#   'TCGA-K4-A54R-01A',
#   'TCGA-XF-A9T0-01A',
#   'TCGA-ZF-A9RC-01A'],
#  'ARSK': ['TCGA-4Z-AA7W-01A', 'TCGA-DK-A3WW-01A', 'TCGA-YC-A89H-01A'],
#  'ART1': ['TCGA-2F-A9KP-01A',
#   'TCGA-2F-A9KR-01A',
#   'TCGA-G2-A3VY-01A',
#   'TCGA-XF-AAML-01A'],
#  'ART3': ['TCGA-2F-A9KO-01A',
#   'TCGA-DK-A6AW-01A',
#   'TCGA-XF-A9ST-01A',
#   'TCGA-YC-A89H-01A',
#   'TCGA-ZF-AA4V-01A'],
#  ...}

# %%
test_genes = ['SMAD4','SMAD2','SMAD3']
list_vals=[]
m='discover'
for gx in test_genes[:]:
    nbx = len(dict_cg_cg_nb[m][gx])
    patientsx = len(dict_gene_vs_patients[gx])
    
    patientsy_union = set()
    patientsy_intersection= set()
    sig_count=0
    for i,gy in enumerate(dict_cg_cg_nb[m][gx]):
        if dict_cg_cg_nb[m][gx][gy]<0.05:
            sig_count+=1
        if i==0:
            patientsy_intersection = set(dict_gene_vs_patients[gy])
        else:
            patientsy_intersection.intersection(set(dict_gene_vs_patients[gy]))
        
        patientsy_union.update(dict_gene_vs_patients[gy])
    
        
    print(dict_cg_cg_nb[m][gx], nbx,sig_count, patientsx, len(patientsy_union),len(patientsy_intersection))
    list_vals.append([gx,nbx,sig_count, patientsx])#,len(patientsy_union),len(patientsy_intersection)])

cols = ['gene','neighbors', 'sig_nb','patients']
# 'union_neighbor_patients','intersection_neighbor_patients']

df_test = pd.DataFrame(list_vals,columns=cols)
df_test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-917a499d54aa> in <module>()
#       3 m='discover'
#       4 for gx in test_genes[:]:
# ----> 5     nbx = len(dict_cg_cg_nb[m][gx])
#       6     patientsx = len(dict_gene_vs_patients[gx])
#       7
#
# KeyError: 'SMAD4'

# %%
s = set()
for i,gx in enumerate(test_genes[:]):
    s2=set()
    for j,gy in enumerate(dict_cg_cg_nb[m][gx]):
        s2.update(dict_gene_vs_patients[gy])
    print(len(s2))
    
    if i==0:
        s.update(s2)
    else:
        s.intersection_update(s2)

len(s)
# Out:
# 39
# 380
# 126
# 26

# %%
for gx in test_genes:
    print(gx,':',list(dict_cg_cg_nb[m][gx]))
# Out:
# SMAD4 : ['SMAD3', 'SMAD2']
# SMAD2 : ['SMAD4', 'TP53', 'SMAD3', 'GNAS', 'TPR', 'MYO5A', 'PREX2', 'CREBBP', 'EP300', 'UBR5']
# SMAD3 : ['SMAD4', 'SMAD2', 'SETD2', 'FLNA']

# %%
# Out:
# 2.995732273553991
